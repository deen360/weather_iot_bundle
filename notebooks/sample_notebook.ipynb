# %% [markdown]
# # Default notebook
#
# This default notebook is executed using a Lakeflow job as defined in resources/sample_job.job.yml.

# %%
# Set default catalog and schema
catalog = dbutils.widgets.get("catalog")
schema = dbutils.widgets.get("schema")
spark.sql(f"USE CATALOG {catalog}")
spark.sql(f"USE SCHEMA {schema}")

# %%
import sys

sys.path.append("../src")
from weather_iot_bundle import taxis

taxis.find_all_taxis().show(10)

# %%
from pyspark.sql import SparkSession
import sys

# Initialize local Spark
spark = SparkSession.builder \
    .appName("LocalCompatibilityTest") \
    .master("local[*]") \
    .getOrCreate()

print(f"✅ Local Spark Version: {spark.version}")
print(f"🐍 Python Executable: {sys.executable}")
# Out:
# ✅ Local Spark Version: 3.5.0
# 🐍 Python Executable: c:\Users\TBR44\Desktop\databricks\weather\weather_iot_bundle\venv_spark\Scripts\python.exe

# %%
# Out:
# hello
